# %%
class Car:
    def __init__(self,saf,wheels=4):#saf deful deger yazmazsan asagida
        self.wheels = wheels        #car init icine yazmak zorundasin
        self.saf=saf
        # We'll say that all cars, no matter their engine, have four wheels by default.

class Gasoline(Car):
    def __init__(self,saf=98,engine='Gasoline',tank_cap=20):
        Car.__init__(self,saf) 
        #buraya yazdigin safi yukarda yazmak zorundasin ve ya yukardakinda defult olacak yada nesne atamasinda deger olacak
        #eger car icinde saf a defult atar car initten safi silrsen ust tarafa veya nesne atamasinda saf a girdigin degerin onemi yok
        self.engine = engine
        self.tank_cap = tank_cap # represents fuel tank capacity in gallons
        self.tank = 0
        
    def refuel(self):
        self.tank = self.tank_cap
        
    
class Electric(Car):
    def __init__(self,saf=208,engine='Electric',kWh_cap=60):
        Car.__init__(self,saf)
        self.engine = engine
        self.kWh_cap = kWh_cap # represents battery capacity in kilowatt-hours
        self.kWh = 0
    
    def recharge(self):
        self.kWh = self.kWh_cap


        
#yilmaz=Electric()        
#galip=Gasoline()        
prius = Hybrid()#????  burdaki neden engine degerine esit oluyo ve ilk iki deger bi ise yaramiyo
#print(prius.kWh)####bunuun ciktisi neden 5 veriyor "Hybrid" vermesi gerek
print(prius.tank_cap)#???? neden hybrid teki tank kapasitesini almiyor gasolindekini aliyor
print(prius.kWh_cap)#???? neden hybrid teki kwh i almiyor elektriktekini aliyor
#print(galip.wheels)
#print(galip.saf)
print(prius.engine)
#???? maden hybrid teki tank_cap ve kWh_cap degerini hic kullanmiyor neden giriyoruz



class Hybrid(Gasoline, Electric):
    def __init__(self):
        Gasoline.__init__(self)
        Electric.__init__(self)

#yilmaz=Electric()        
#galip=Gasoline()        
prius = Hybrid()#????  burdaki neden engine degerine esit oluyo ve ilk iki deger bi ise yaramiyo
#print(prius.kWh)####bunuun ciktisi neden 5 veriyor "Hybrid" vermesi gerek
print(prius.tank_cap)#???? neden hybrid teki tank kapasitesini almiyor gasolindekini aliyor
print(prius.kWh_cap)#???? neden hybrid teki kwh i almiyor elektriktekini aliyor
#print(galip.wheels)
#print(galip.saf)
print(prius.engine) #bunu neden elektrik aldi sonucunda
#???? maden hybrid teki tank_cap ve kWh_cap degerini hic kullanmiyor neden giriyoruz



class Hybrid(Gasoline, Electric):
    def __init__(self,engine='Hybrid'):
        Gasoline.__init__(self,engine)
        Electric.__init__(self,engine)
        
#yilmaz=Electric()        
#galip=Gasoline()        
prius = Hybrid()#????  burdaki neden engine degerine esit oluyo ve ilk iki deger bi ise yaramiyo
#print(prius.kWh)####bunuun ciktisi neden 5 veriyor "Hybrid" vermesi gerek
print(prius.tank_cap)#???? neden hybrid teki tank kapasitesini almiyor gasolindekini aliyor
print(prius.kWh_cap)#???? neden hybrid teki kwh i almiyor elektriktekini aliyor
#print(galip.wheels)
#print(galip.saf)
print(prius.engine)#sonu enteresan sekilde yine elektrik cikti
#???? maden hybrid teki tank_cap ve kWh_cap degerini hic kullanmiyor neden giriyoruz
